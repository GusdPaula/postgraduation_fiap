# %% [markdown]
# <a href="https://colab.research.google.com/github/GusdPaula/postgraduation_fiap/blob/main/fase_3/techchallenge_3_upload_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.cloud import bigquery
from pandas_gbq import to_gbq

# %%
df_saude = pd.read_excel('/content/pnad_covid19_202011_saude_BR_GR_UF.xlsx', header=8)
df_saude.drop(0,axis=0,inplace=True)
df_saude
# Out:
#                                                Indicador Nível Territorial  \
# 1      Pessoas que apresentaram algum dos sintoma(s) ...              País
# 2      Pessoas que apresentaram algum dos sintoma(s) ...              País
# 3      Pessoas que apresentaram algum dos sintoma(s) ...              País
# 4      Pessoas que apresentaram algum dos sintoma(s) ...              País
# 5      Pessoas que apresentaram algum dos sintoma(s) ...              País
# ...                                                  ...               ...
# 13026  CV - Percentual de pessoas com diagnóstico méd...     Grande Região
# 13027  CV - Percentual de pessoas com diagnóstico méd...     Grande Região
# 13028  CV - Percentual de pessoas com diagnóstico méd...     Grande Região
# 13029  CV - Percentual de pessoas com diagnóstico méd...     Grande Região
# 13030  CV - Percentual de pessoas com diagnóstico méd...     Grande Região
#
# ...

# %%
df_saude.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13030 entries, 1 to 13030
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Indicador                       13030 non-null  object
#  1   Nível Territorial               13030 non-null  object
#  2   Abertura Territorial            13030 non-null  object
#  3   Variável de abertura 1          13030 non-null  object
#  4   Categoria de abertura 1         13030 non-null  object
#  5   Variável de abertura 2          13030 non-null  object
#  6   Categoria de abertura 2         13030 non-null  object
#  7   Maio                            13030 non-null  float64
#  8   Junho                           13030 non-null  float64
#  9   Situação Maio para Junho        13030 non-null  object
#  10  Julho                           13030 non-null  float64
#  11  Situação Junho para Julho       13030 non-null  object
# ...

# %%
# Defining th client
bigquery_client = bigquery.Client()

project_id = 'tech-chlg'
dataset_id = 'pnad_covid'
source_table = 'pnad_covid19_202011_saude_BR_GR_UF'
target_table = 'pnad_covid.pnad_covid19_202011_saude_BR_GR_UF'

# %%
# Write to bigquery
to_gbq(df_saude, target_table, project_id, if_exists='replace')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 729.70it/s]

# %%
# With BigQuery DataFrames, you can use many familiar Pandas methods, but the
# processing happens BigQuery rather than the runtime, allowing you to work with larger
# DataFrames that would otherwise not fit in the runtime memory.
# Learn more here: https://cloud.google.com/python/docs/reference/bigframes/latest

import bigframes.pandas as bf

bf.options.bigquery.location = "africa-south1" #this variable is set based on the dataset you chose to query
bf.options.bigquery.project = "tech-chlg" #this variable is set based on the dataset you chose to query

# %%
df = bf.read_gbq("tech-chlg.pnad_covid.pnad_covid19_202011_saude_BR_GR_UF") #this variable is set based on the dataset you chose to query

# %%
# BigFrames can work with tables that are too large to fit in the notebook memory.
# Look at the first 20 rows.
df.head(20)
# Out:
# Query job fd7a799d-c48f-435e-9dff-95e4e3cb0e51 is DONE. 3.4 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=tech-chlg&j=bq:africa-south1:fd7a799d-c48f-435e-9dff-95e4e3cb0e51&page=queryresults">Open Job</a>
#                                             Indicador Nível Territorial  \
# 0   Distribuição das pessoas que fizeram algum tes...     Grande Região
# 1   CV - Pessoas com diagnóstico médico de alguma ...     Grande Região
# 2   Distribuição das pessoas que procuraram atendi...     Grande Região
# 3   Pessoas que não procuraram atendimento em esta...     Grande Região
# 4   Distribuição das pessoas que apresentaram o si...     Grande Região
# 5   Percentual de pessoas que procuraram estabelec...     Grande Região
# 6   CV - Percentual de pessoas que procuraram esta...     Grande Região
# 7   CV – Percentual de pessoas que procuraram aten...              País
# 8   CV - Pessoas que apresentaram o sintoma de per...              País
# ...

# %%
df_trabalho = pd.read_excel('/content/pnad_covid19_202011_trabalho_BR_GR_UF (1).xlsx', header=5)
df_trabalho.drop(0,axis=0,inplace=True)
df_trabalho
# Out:
#                                                Indicador Nível Territorial  \
# 1                      População Residente (mil pessoas)              País
# 2                      População Residente (mil pessoas)              País
# 3                      População Residente (mil pessoas)              País
# 4                      População Residente (mil pessoas)              País
# 5                      População Residente (mil pessoas)              País
# ...                                                  ...               ...
# 14618  CV - Distribuição das pessoas que não procurar...     Grande Região
# 14619  CV - Distribuição das pessoas que não procurar...     Grande Região
# 14620  CV - Distribuição das pessoas que não procurar...     Grande Região
# 14621  CV - Distribuição das pessoas que não procurar...     Grande Região
# 14622  CV - Distribuição das pessoas que não procurar...     Grande Região
#
#       Abertura Territorial Variável de abertura 1  \
# ...

# %%
to_gbq(df_trabalho, 'pnad_covid.pnad_covid19_202011_trabalho_BR_GR_UF', project_id, if_exists='replace')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 6898.53it/s]

# %%
df = bf.read_gbq("tech-chlg.pnad_covid.pnad_covid19_202011_trabalho_BR_GR_UF") #this variable is set based on the dataset you chose to query
# BigFrames can work with tables that are too large to fit in the notebook memory.
# Look at the first 20 rows.
df.head(20)
# Out:
# Query job 4fdee766-60f9-4b2d-b6da-c2fa5f8259dd is DONE. 3.9 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=tech-chlg&j=bq:africa-south1:4fdee766-60f9-4b2d-b6da-c2fa5f8259dd&page=queryresults">Open Job</a>
#                                             Indicador Nível Territorial  \
# 0   Pessoas não ocupadas que não procuraram trabal...     Grande Região
# 1                      Pessoas ocupadas (mil pessoas)     Grande Região
# 2   CV - Pessoas não ocupadas que não procuraram t...              País
# 3   Pessoas fora da força de trabalho na semana de...     Grande Região
# 4                   População Residente (mil pessoas)     Grande Região
# 5        CV - Pessoas responsáveis pelo domicílio (%)     Grande Região
# 6   CV - Rendimento real domiciliar per capita méd...              País
# 7   Percentual de pessoas não ocupadas que não pro...     Grande Região
# 8   Distribuição das pessoas fora da força de trab...              País
# ...

# %%
df_escola_emprestimos_itens = pd.read_excel('/content/pnad_covid19_202011_escola_emprestimos_itens_de_limpeza_BR_GR_UF.xlsx', header=5)
df_escola_emprestimos_itens.drop(0,axis=0,inplace=True)
df_escola_emprestimos_itens
# Out:
#                                                Indicador Nível Territorial  \
# 1            Pessoas que frequentam escola (mil pessoas)              País
# 2            Pessoas que frequentam escola (mil pessoas)              País
# 3            Pessoas que frequentam escola (mil pessoas)              País
# 4            Pessoas que frequentam escola (mil pessoas)     Grande Região
# 5            Pessoas que frequentam escola (mil pessoas)     Grande Região
# ...                                                  ...               ...
# 14252  CV – Distribuição das pessoas que frequentam e...     Grande Região
# 14253  CV – Distribuição das pessoas que frequentam e...     Grande Região
# 14254  CV – Distribuição das pessoas que frequentam e...     Grande Região
# 14255  CV – Distribuição das pessoas que frequentam e...     Grande Região
# 14256  CV – Distribuição das pessoas que frequentam e...     Grande Região
#
#       Abertura Territorial      Variável de abertura 1  \
# ...

# %%
to_gbq(df_escola_emprestimos_itens, 'pnad_covid.pnad_covid19_202011_escola_emprestimos_itens_de_limpeza_BR_GR_UF', project_id, if_exists='replace')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 9137.92it/s]

# %%
df = bf.read_gbq("tech-chlg.pnad_covid.pnad_covid19_202011_escola_emprestimos_itens_de_limpeza_BR_GR_UF") #this variable is set based on the dataset you chose to query
# BigFrames can work with tables that are too large to fit in the notebook memory.
# Look at the first 20 rows.
df.head(20)
# Out:
# Query job 5439caa4-6d0b-4c30-a079-2a80dae2e31d is DONE. 3.8 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=tech-chlg&j=bq:africa-south1:5439caa4-6d0b-4c30-a079-2a80dae2e31d&page=queryresults">Open Job</a>
#                                             Indicador Nível Territorial  \
# 0                   População residente (mil pessoas)     Grande Região
# 1              CV – Pessoas que frequentam escola (%)     Grande Região
# 2             Distribuição da população residente (%)              País
# 3   CV – Distribuição das pessoas que frequentam e...              País
# 4   CV – Percentual de pessoas que frequentam esco...     Grande Região
# 5                   População residente (mil pessoas)     Grande Região
# 6              CV – Pessoas que frequentam escola (%)     Grande Região
# 7              CV – Pessoas que frequentam escola (%)     Grande Região
# 8   CV - Distribuição das pessoas que frequentam e...              País
# ...

# %%
df_saude_uf = pd.read_excel('/content/pnad_covid19_202011_saude_BR_GR_UF.xlsx', sheet_name='Saúde UF', header=7)
df_saude_uf.drop(0,axis=0,inplace=True)
df_saude_uf
# Out:
#                                                Indicador  \
# 1      Pessoas que apresentaram algum dos sintoma(s) ...
# 2      CV - Pessoas que apresentaram algum dos sintom...
# 3      Percentual de pessoas que apresentaram algum d...
# 4      CV - Percentual de pessoas que apresentaram al...
# 5      Pessoas que apresentaram sintomas referenciado...
# ...                                                  ...
# 17330  CV - Percentual de pessoas com diagnóstico méd...
# 17331  CV - Percentual de pessoas com diagnóstico méd...
# 17332  CV - Percentual de pessoas com diagnóstico méd...
# 17333  CV - Percentual de pessoas com diagnóstico méd...
# 17334  CV - Percentual de pessoas com diagnóstico méd...
#
#           Nível Territorial Abertura Territorial Variável de abertura 1  \
# 1      Unidade da Federação             Rondônia                      -
# 2      Unidade da Federação             Rondônia                      -
# ...

# %%
# Defining th client
bigquery_client = bigquery.Client()

project_id = 'tech-chlg'
dataset_id = 'pnad_covid'
target_table = 'pnad_covid.saude_uf'

# %%
# Write to bigquery
to_gbq(df_saude_uf, target_table, project_id, if_exists='replace')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 7710.12it/s]

# %%
df_trabalho_uf = pd.read_excel('/content/pnad_covid19_202011_trabalho_BR_GR_UF.xlsx', sheet_name='Trabalho UF', header=5)
df_trabalho_uf.drop(0,axis=0,inplace=True)
df_trabalho_uf
# Out:
#                                                Indicador  \
# 1                      População Residente (mil pessoas)
# 2                           CV - População Residente (%)
# 3      Pessoas de 14 anos ou mais de idade (mil pessoas)
# 4           CV - Pessoas de 14 anos ou mais de idade (%)
# 5                         Pessoas ocupadas (mil pessoas)
# ...                                                  ...
# 17600  CV - Distribuição das pessoas responsáveis pel...
# 17601  CV - Distribuição das pessoas responsáveis pel...
# 17602  CV - Distribuição das pessoas responsáveis pel...
# 17603  Proxy da subutilização da força de trabalho (m...
# 17604  CV - Proxy da subutilização da força de trabal...
#
#           Nível Territorial Abertura Territorial Variável de abertura 1  \
# 1      Unidade da Federação             Rondônia                      -
# 2      Unidade da Federação             Rondônia                      -
# ...

# %%
# Defining th client
bigquery_client = bigquery.Client()

project_id = 'tech-chlg'
dataset_id = 'pnad_covid'
target_table = 'pnad_covid.trabalho_uf'

# Write to bigquery
to_gbq(df_trabalho_uf, target_table, project_id, if_exists='replace')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 8272.79it/s]

# %%
df_escola_emprestimos_itens_uf = pd.read_excel('/content/pnad_covid19_202011_escola_emprestimos_itens_de_limpeza_BR_GR_UF.xlsx', sheet_name='Outros UF', header=5)
df_escola_emprestimos_itens_uf.drop(0,axis=0,inplace=True)
df_escola_emprestimos_itens_uf.head()
# Out:
#                                      Indicador     Nível Territorial  \
# 1  Pessoas que frequentam escola (mil pessoas)  Unidade da Federação
# 2  Pessoas que frequentam escola (mil pessoas)  Unidade da Federação
# 3  Pessoas que frequentam escola (mil pessoas)  Unidade da Federação
# 4  Pessoas que frequentam escola (mil pessoas)  Unidade da Federação
# 5  Pessoas que frequentam escola (mil pessoas)  Unidade da Federação
#
#   Abertura Territorial Variável de abertura 1 Categoria de abertura 1  \
# 1             Rondônia                   Sexo                   Total
# 2             Rondônia                   Sexo                   Homem
# 3             Rondônia                   Sexo                  Mulher
# 4                 Acre                   Sexo                   Total
# 5                 Acre                   Sexo                   Homem
#
#   Variável de abertura 2 Categoria de abertura 2       Julho      Agosto  \
# ...

# %%
# Defining th client
bigquery_client = bigquery.Client()

project_id = 'tech-chlg'
dataset_id = 'pnad_covid'
target_table = 'pnad_covid.escola_item_uf'

# Write to bigquery
to_gbq(df_escola_emprestimos_itens_uf, target_table, project_id, if_exists='replace')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 7724.32it/s]
